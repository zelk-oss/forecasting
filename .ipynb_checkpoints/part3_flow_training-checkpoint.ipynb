# %%
# For debugging
# %load_ext autoreload
# %autoreload 2

# %%
from copy import deepcopy

import torch
import torch.nn
import torch.optim
from torch.utils.data import DataLoader

import xarray as xr
import numpy

from tqdm.notebook import tqdm 

from neural_net_old import get_net
from constants import *

import matplotlib.pyplot as plt

# %%
def plot_q(q, ax=None, title='', cbar=False):
    # Plot a 2D vorticity field. q should be shape (H, W).
    if ax is None:
        fig, ax = plt.subplots()
    q = np.asarray(q).squeeze()          # ensure 2-D
    assert q.ndim == 2, f"Expected 2D array, got shape {q.shape}"
    qmax = np.abs(q).max()
    pc = ax.pcolormesh(
        np.linspace(0, 2*np.pi, q.shape[1] + 1),   # (W+1,) cell edges
        np.linspace(0, 2*np.pi, q.shape[0] + 1),   # (H+1,) cell edges
        q, cmap='seismic', vmin=-qmax, vmax=qmax,
        shading='flat'
    )
    ax.set_aspect('equal')
    ax.set_title(title, fontsize=9)
    ax.set_xticks([]); ax.set_yticks([])
    return pc

# %%
torch.manual_seed(42)

# %% [markdown]
# # Settings

# %%
device = torch.device("cuda")
dtype = torch.bfloat16

batch_size = 4
n_epochs = 10000
n_layers = 4

# %% [markdown]
# # Load data
# Training data will have shape (time, 2, dim, dim). On the channels dimension we have concatenated the normalized states and the normalized residuals.

# %%
# Load only first 4 time steps
ds_train = xr.open_zarr("../dataset_gen/dataset/train_q.zarr")["q"].isel(time=slice(4,9)).compute()

print("New shape:", ds_train.shape)  # should be (4, nx, ny)

# Convert to torch
data = torch.as_tensor(ds_train.values, dtype=dtype).unsqueeze(1)

# Split input and residual
data_in = data[:-1]
data_res = data[1:] - data[:-1]

# --- compute normalization statistics on the fly ---
in_mean  = data_in.mean(dim=(0,2,3), keepdim=True)
in_std   = data_in.std(dim=(0,2,3), keepdim=True)

res_mean = data_res.mean(dim=(0,2,3), keepdim=True)
res_std  = data_res.std(dim=(0,2,3), keepdim=True)

# --- normalize ---
train_data = torch.cat((
    (data_in - in_mean) / in_std,
    (data_res - res_mean) / res_std
), dim=1)

# Normalize data
#train_data = torch.cat((
#    (torch.as_tensor(ds_train.values[:-1], dtype=dtype) - in_mean) / in_std,
#    (torch.as_tensor(ds_train.values[1:] - ds_train.values[:-1], dtype=dtype) - res_mean) / res_std
#), dim=1)


# Channel 0 = field, Channel 1 = residual
field = train_data[:, 0]
residual = train_data[:, 1]

print("field mean:", field.mean().item())
print("field std :", field.std().item())

print("residual mean:", residual.mean().item())
print("residual std :", residual.std().item())

del ds_train

train_loader = DataLoader(
    train_data,
    batch_size=batch_size,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

print("len train loader:", len(train_loader))
# Out:
# New shape: (5, 512, 512)
# field mean: -1.519918441772461e-06
# field std : 1.0
# residual mean: -2.8252601623535156e-05
# residual std : 1.0
# len train loader: 1

# %%
train_data.shape[0]
# Out:
# 4

# %%
n_samples = train_data.shape[0]

for i in range(n_samples):

    field = train_data[i, 0].float().cpu().numpy()
    residual = train_data[i, 1].float().cpu().numpy()

    vmax_field = abs(field).max()
    vmax_res = abs(residual).max()

    fig, axes = plt.subplots(1, 2, figsize=(10,4))

    im0 = axes[0].imshow(field, vmin=-vmax_field, vmax=vmax_field)
    axes[0].set_title(f"Field q_t (sample {i})")
    plt.colorbar(im0, ax=axes[0], fraction=0.046)

    im1 = axes[1].imshow(residual, vmin=-vmax_res, vmax=vmax_res)
    axes[1].set_title(f"Residual q_(t+1) - q_t (sample {i})")
    plt.colorbar(im1, ax=axes[1], fraction=0.046)

    plt.tight_layout()
    plt.show()

# %%
ds_val = xr.open_zarr("../data/sqg_val.zarr")["q"].isel(time=slice(4, 15)).compute() # validation data 
val_data = torch.cat((
    (torch.as_tensor(ds_val.values[:-1], dtype=dtype)-in_mean) / in_std,
    (torch.as_tensor(ds_val.values[1:]-ds_val.values[:-1], dtype=dtype)-res_mean) / res_std
), dim=1)
print(ds_val.time.shape) 

print("val mean:", val_data.mean().item())
print("val std :", val_data.std().item())

del ds_val

val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# (5,)
# val mean: 1.4093820936977863e-06
# val std : 0.9809098839759827

# %% [markdown]
# # Define neural network
# ConvNet

# %%
n_features = 256
#n_embedding = 32

wave_length = 1.0

lr = 5e-3

model = get_net(
    # Input: intermediate state (1) + initial conditions (1)
    n_input=2,
    n_output=1, n_layers = n_layers,  
    n_features=n_features, mult=2,
    # Activation of pseudo time
    use_time = True, 
    #n_embedding=n_embedding, 
    wave_length=wave_length,
    device=device, dtype=dtype
)
optim = torch.optim.Adam(model.parameters(), lr=lr) # maybe use Adam w?

# %% [markdown]
# - fixing t=0.5

# %%
import json
import matplotlib.pyplot as plt

train_losses = []
val_losses = []

pbar_epoch = tqdm(range(n_epochs))
mse_val = torch.inf
best_mse = torch.inf
best_model = None

for epoch_idx, _ in enumerate(pbar_epoch):
    pbar_train = tqdm(iter(train_loader), total=len(train_loader), leave=True)
    # Training loop
    model = model.train()
    epoch_train_loss = 0
    epoch_train_samples = 0
    for batch_idx, batch in enumerate(pbar_train):        
        batch = batch.to(device=device, dtype=dtype)
        
        # data_in = standardized field 
        # data_target = standardized residual 
        data_in, data_target = batch.split((1, 1), dim=1)
        print("data in mean and std:", data_in.mean().item(), data_in.std().item()) 
        print("data target mean and std:", data_target.mean().item(), data_target.std().item()) 

        noise = torch.randn_like(data_target)
        pseudo_time = torch.linspace(0, 1, batch.shape[0]+1, device=device, dtype=dtype)[:-1, None]
        time_shift = torch.rand(1, device=device, dtype=dtype)
        pseudo_time = (pseudo_time + time_shift) % 1
        # copilot suggestion
        #pseudo_time = torch.full((batch.shape[0], 1), 0.5, device=device, dtype=dtype)

        # linear interpolant 
        intermediate_state = pseudo_time[..., None, None] * data_target \
            + (1 - pseudo_time[..., None, None]) * noise
        # simple derivative 
        target_velocity = data_target - noise

        # input = interpolant + standardized state 
        input_tensor = torch.cat((intermediate_state, data_in), dim=1)
        optim.zero_grad()

        # model takes input + pseudo time 
        prediction = model(input_tensor, pseudo_time)
        print("prediction mean and std:", prediction.mean().item(), prediction.std().item())
        print("target velocity mean and std:", target_velocity.mean().item(), target_velocity.std().item())

        
        error = (prediction - target_velocity).pow(2)
        mse_train = error.mean()
        mse_train.backward()
        optim.step()
        #scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optim, T_max=n_epochs, eta_min=1e-6)
        # at end of each epoch:
        #scheduler.step()

        # Accumulate training loss (same weighted avg logic as val)
        curr_se = error.mean(dim=(1, 2, 3)).sum().item()

        # average MSE per sample over epoch
        epoch_train_loss = (epoch_train_loss * epoch_train_samples + curr_se) / (epoch_train_samples + len(batch))
        epoch_train_samples += len(batch)

        pbar_train.set_postfix(mse_train=mse_train.item(), mse_val=mse_val)

    train_losses.append(epoch_train_loss)

    """
    mse_val = 0
    samples_val = 0
    pbar_val = tqdm(enumerate(val_loader), total=len(val_loader), leave=False)
    
    # Validation loop
    model = model.eval()
    for k, batch in pbar_val:        
        batch = batch.to(device=device, dtype=dtype)
        
        data_in, data_target = batch.split((1,1), dim=1)
        
        noise = torch.randn_like(data_target)
        pseudo_time = torch.linspace(0, 1, batch.shape[0]+1, device=device, dtype=dtype)[:-1, None]
        time_shift = torch.rand(1, device=device, dtype=dtype)
        pseudo_time = (pseudo_time + time_shift) % 1
        #pseudo_time = torch.full((batch.shape[0], 1), 0.5, device=device, dtype=dtype)

        intermediate_state = pseudo_time[..., None, None] * data_target \
            + (1 - pseudo_time[..., None, None]) * noise
        target_velocity = data_target - noise
        input_tensor = torch.cat((intermediate_state, data_in), dim=1)
        
        with torch.no_grad():
            prediction = model(input_tensor, pseudo_time)
        error = (prediction - target_velocity).pow(2)
        curr_se = error.mean(dim=(1, 2, 3)).sum().item()
        mse_val = (mse_val * samples_val + curr_se) / (samples_val + len(batch))
        samples_val += len(batch)

    val_losses.append(mse_val)
    pbar_train.set_postfix(mse_train=mse_train.item(), mse_val=mse_val)
    pbar_epoch.set_postfix(train=epoch_train_loss, val=mse_val)
    """
    
    # Save losses to JSON
    loss_history = {"train": train_losses} #, "val": val_losses}
    with open("loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

    # Save loss plot
    fig, ax = plt.subplots(figsize=(8, 5))
    epochs = range(1, epoch_idx + 2)
    ax.plot(epochs, train_losses, label="Train MSE", marker="o", markersize=3)
    #ax.plot(epochs, val_losses,   label="Val MSE",   marker="o", markersize=3)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("MSE")
    ax.set_title("Training Loss")
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig("loss_history.png", dpi=150)
    plt.close(fig)
        
    if mse_val < 0.999 * best_mse:
        best_mse = mse_val
        best_model = deepcopy(model).cpu()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.09814453125 0.09765625
# target velocity mean and std: -0.0001888275146484375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -5.78125 0.953125
# target velocity mean and std: 0.0003261566162109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 8.375 1.3125
# target velocity mean and std: 0.002532958984375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -2.546875 0.51953125
# target velocity mean and std: 5.173683166503906e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.80859375 0.279296875
# target velocity mean and std: -0.00015926361083984375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 9.3125 0.55859375
# target velocity mean and std: -3.7670135498046875e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -1.5078125 0.2314453125
# target velocity mean and std: 0.00018596649169921875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -2.734375 0.24609375
# target velocity mean and std: -0.00011730194091796875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 1.1171875 0.267578125
# target velocity mean and std: 0.001251220703125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 1.015625 0.8046875
# target velocity mean and std: 0.000621795654296875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.41015625 0.41796875
# target velocity mean and std: 0.000720977783203125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 1.640625 0.47265625
# target velocity mean and std: 0.000576019287109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.056640625 0.34765625
# target velocity mean and std: 0.002227783203125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -1.34375 0.26171875
# target velocity mean and std: 0.000171661376953125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.271484375 0.26171875
# target velocity mean and std: -0.00090789794921875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 1.2109375 0.265625
# target velocity mean and std: 0.001129150390625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.205078125 0.1591796875
# target velocity mean and std: -0.00189971923828125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -1.109375 0.11669921875
# target velocity mean and std: 0.0003490447998046875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.04345703125 0.1103515625
# target velocity mean and std: 0.00154876708984375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 1.046875 0.1875
# target velocity mean and std: -0.0019378662109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.31640625 0.1103515625
# target velocity mean and std: -6.628036499023438e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.77734375 0.1083984375
# target velocity mean and std: -0.00019741058349609375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.419921875 0.11181640625
# target velocity mean and std: 0.00127410888671875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.5703125 0.197265625
# target velocity mean and std: 0.0007171630859375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.6953125 0.25
# target velocity mean and std: 0.00119781494140625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.1142578125 0.1923828125
# target velocity mean and std: 0.000308990478515625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.5546875 0.1748046875
# target velocity mean and std: 0.0003147125244140625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.1982421875 0.30859375
# target velocity mean and std: 0.0015411376953125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.55078125 0.390625
# target velocity mean and std: -0.00019073486328125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.455078125 0.54296875
# target velocity mean and std: 0.00080108642578125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.1259765625 0.427734375
# target velocity mean and std: -0.00107574462890625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.474609375 0.45703125
# target velocity mean and std: 0.0005340576171875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.1572265625 0.53125
# target velocity mean and std: -0.0003566741943359375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.302734375 0.80078125
# target velocity mean and std: -0.000957489013671875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.341796875 0.9296875
# target velocity mean and std: -0.00101470947265625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.07470703125 0.76953125
# target velocity mean and std: -1.1026859283447266e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.3828125 0.71484375
# target velocity mean and std: 0.0009765625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.228515625 0.83203125
# target velocity mean and std: -0.000972747802734375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.134765625 1.03125
# target velocity mean and std: 0.00022792816162109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.25 0.8359375
# target velocity mean and std: -0.00048828125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.04052734375 0.9375
# target velocity mean and std: 0.000354766845703125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.19921875 0.69921875
# target velocity mean and std: -4.076957702636719e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.2373046875 0.73046875
# target velocity mean and std: -0.00159454345703125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.05322265625 0.78125
# target velocity mean and std: -0.00067901611328125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.1728515625 0.65234375
# target velocity mean and std: -0.000370025634765625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.185546875 0.6953125
# target velocity mean and std: -3.6716461181640625e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.0625 0.58203125
# target velocity mean and std: -0.001953125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.1142578125 0.60546875
# target velocity mean and std: -0.00099945068359375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.158203125 0.6796875
# target velocity mean and std: 0.002105712890625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.05322265625 0.7109375
# target velocity mean and std: -0.000621795654296875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.11328125 0.640625
# target velocity mean and std: 0.00182342529296875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.1611328125 0.67578125
# target velocity mean and std: 0.00057220458984375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.11328125 0.578125
# target velocity mean and std: 0.00086212158203125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.046142578125 0.7734375
# target velocity mean and std: -0.00016498565673828125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.107421875 0.66796875
# target velocity mean and std: -0.0004177093505859375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.0859375 0.765625
# target velocity mean and std: -0.00010585784912109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.0242919921875 0.68359375
# target velocity mean and std: -0.001983642578125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.09326171875 0.8125
# target velocity mean and std: 0.000514984130859375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.0869140625 0.859375
# target velocity mean and std: -8.106231689453125e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.00732421875 0.76953125
# target velocity mean and std: -0.00113677978515625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.08203125 0.84765625
# target velocity mean and std: 0.0003452301025390625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.09130859375 0.75390625
# target velocity mean and std: -0.0011444091796875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.04736328125 0.91796875
# target velocity mean and std: -0.000820159912109375 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.030029296875 0.86328125
# target velocity mean and std: 0.000438690185546875 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.056884765625 0.89453125
# target velocity mean and std: -0.00141143798828125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.04638671875 0.8359375
# target velocity mean and std: -6.628036499023438e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.02099609375 0.93359375
# target velocity mean and std: -8.0108642578125e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.059326171875 0.88671875
# target velocity mean and std: -0.000370025634765625 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: -0.0458984375 0.734375
# target velocity mean and std: 1.0848045349121094e-05 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.004364013671875 0.7109375
# target velocity mean and std: 0.00141143798828125 1.4140625
#   0%|          | 0/1 [00:00<?, ?it/s]
# data in mean and std: -1.519918441772461e-06 1.0
# data target mean and std: -2.8252601623535156e-05 1.0
# prediction mean and std: 0.045166015625 0.85546875
# target velocity mean and std: -0.00116729736328125 1.4140625

# %% [markdown]
# # Store best model

# %%
import os 
if best_model is not None:
    # Save best model checkpoint
    ckpt = {
        "model_state_dict": best_model.state_dict(),  # Save best
        "optimizer_state_dict": optim.state_dict(),
        "best_mse": best_mse,  # Track best MSE
        "config": {
            "n_input": 2,  
            "n_output": 1,
            "n_features": n_features,
            "mult": 2,
            "use_time": True,       
            "wave_length": wave_length,
        }
    }
    torch.save(ckpt, os.path.join("..", "data", "best_flowcondmodel_test_convnet.ckpt"))
    print(f"Saved best checkpoint (MSE={best_mse:.6f}) to ../data/best_flowmodel_test.ckpt")
else:
    print("Warning: No model was saved (validation never improved)")
# Out:
# Saved best checkpoint (MSE=0.267334) to ../data/best_flowmodel_test.ckpt
