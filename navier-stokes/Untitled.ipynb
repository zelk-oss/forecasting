# %%
import torch
import numpy as np

# %%
data = torch.load("nse_data_tiny.pt")

print(type(data))
# Out:
# <class 'tuple'>

# %%
if isinstance(data, dict):
    print(data.keys())
else:
    print(len(data))
    print(type(data[0]))
# Out:
# 2
# <class 'torch.Tensor'>

# %%
sample = data[0]
print(type(sample))
print(len(sample))
print(sample[0].shape, sample[1].shape)
# Out:
# <class 'torch.Tensor'>
# 2
# torch.Size([100, 256, 256]) torch.Size([100, 256, 256])

# %%
import xarray as xr

ds = xr.open_dataset("../../../fm_tutorial/dataset_gen/simu_pyqg_512_3.nc").sel(time=slice(60, 149))
print(ds.q.shape) 
print(ds)
# Out:
# (90, 1, 512, 512)
# <xarray.Dataset> Size: 566MB
# Dimensions:  (time: 90, lev: 1, y: 512, x: 512, lev_mid: 0)
# Coordinates:
#   * time     (time) float64 720B 60.0 61.0 62.0 63.0 ... 146.0 147.0 148.0 149.0
#   * lev      (lev) int32 4B 1
#   * y        (y) float64 4kB 0.006136 0.01841 0.03068 ... 6.253 6.265 6.277
#   * x        (x) float64 4kB 0.006136 0.01841 0.03068 ... 6.253 6.265 6.277
#   * lev_mid  (lev_mid) float64 0B
# Data variables:
#     q        (time, lev, y, x) float64 189MB ...
#     u        (time, lev, y, x) float64 189MB ...
#     v        (time, lev, y, x) float64 189MB ...
#     times    (time) float64 720B ...
# Attributes: (12/20)
#     pyqg:beta:       0.0
#     pyqg:dt:         0.0001
#     pyqg:filterfac:  10.0
#     pyqg:L:          6.283185307179586
#     pyqg:M:          262144
#     pyqg:ntd:        8
#     ...              ...
#     pyqg:tc:         0
#     pyqg:tmax:       150
#     pyqg:twrite:     1000
#     pyqg:W:          6.283185307179586
#     title:           pyqg: Python Quasigeostrophic Model
#     reference:       https://pyqg.readthedocs.io/en/latest/index.html

# %%
q = ds["q"].values 
q = q[70:, 0, :, :]    # shape (90, 512, 512)

time_lag = 2

z0_list = []
z1_list = []

for t in range(len(q) - time_lag):
    z0_list.append(q[t])
    z1_list.append(q[t + time_lag])

z0 = torch.tensor(np.stack(z0_list)).float()
z1 = torch.tensor(np.stack(z1_list)).float()

# %%
print(z0.shape, z1.shape)
# Out:
# torch.Size([18, 512, 512]) torch.Size([18, 512, 512])

# %%
torch.save((z0, z1), "my_nse_512.pt")
